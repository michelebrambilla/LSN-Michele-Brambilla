# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
x_train = np.random.uniform(-1.5, 1.5, 5000)
y_train = np.random.uniform(-1.5, 1.5, 5000)
x_valid = np.random.uniform(-1.5, 1.5, 500)
y_valid = np.random.uniform(-1.5, 1.5, 500)
f_target = np.sin(x_valid*x_valid + y_valid*y_valid)

sigma = 0.2;
f_train = np.random.normal(np.sin(x_train*x_train + y_train*y_train), sigma) # actual measures from which we want to guess regression parameters
f_valid = np.random.normal(f_target, sigma)

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes = axes.flatten()

scatter_T = axes[0].scatter(x_valid, y_valid, c=f_target, cmap='jet', s=50, zorder=2, vmin = -1.2, vmax = 1.2, label='target')
cbar_T = plt.colorbar(scatter_T, pad=0.1)
cbar_T.set_label('target') 
axes[0].legend()
axes[0].grid(True)


scatter_e = axes[1].scatter(x_valid, y_valid, c=f_valid, cmap='jet', s=50, zorder=2, vmin = -1.2, vmax = 1.2, label='validation data')
cbar_E = plt.colorbar(scatter_e, pad=0.1)
cbar_E.set_label('validation data')
axes[1].legend()
axes[1].grid(True)


plt.plot();

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Input(shape=(2,)))
model.add(Dense(150, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_61 (Dense)                     │ (None, 150)                 │             450 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_62 (Dense)                     │ (None, 100)                 │          15,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_63 (Dense)                     │ (None, 20)                  │           2,020 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_64 (Dense)                     │ (None, 1)                   │              21 │
# ...

# %%
bsize = 32

X_train = np.column_stack((x_train, y_train))
X_valid = np.column_stack((x_valid, y_valid))

history = model.fit(x=X_train, y=f_train, 
          batch_size=bsize, epochs=50, 
          validation_data=(X_valid, f_valid))
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1975 - mse: 0.1975 - val_loss: 0.1816 - val_mse: 0.1816
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1749 - mse: 0.1749 - val_loss: 0.1713 - val_mse: 0.1713
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1676 - mse: 0.1676 - val_loss: 0.1671 - val_mse: 0.1671
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1618 - mse: 0.1618 - val_loss: 0.1580 - val_mse: 0.1580
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1558 - mse: 0.1558 - val_loss: 0.1529 - val_mse: 0.1529
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1503 - mse: 0.1503 - val_loss: 0.1506 - val_mse: 0.1506
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1447 - mse: 0.1447 - val_loss: 0.1408 - val_mse: 0.1408
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1388 - mse: 0.1388 - val_loss: 0.1352 - val_mse: 0.1352
# Epoch 9/50
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-3, 3, 5000)
y_predicted = np.random.uniform(-3, 3, 5000)

f_target = np.sin(x_predicted*x_predicted + y_predicted*y_predicted)

data_predicted = np.column_stack((x_predicted, y_predicted))
f_predicted = model.predict(data_predicted)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
axes = axes.flatten()

scatter_T = axes[0].scatter(x_predicted, y_predicted, c=f_target, cmap='jet', s=20, zorder=2, vmin = -1.2, vmax = 1.2, label='target')
cbar_T = plt.colorbar(scatter_T, pad=0.1)
cbar_T.set_label('prediction') 
axes[0].legend()
axes[0].grid(True)


scatter_e = axes[1].scatter(x_predicted, y_predicted, c=f_predicted, cmap='jet', s=20, zorder=2, vmin = -1.2, vmax = 1.2, label='prediction')
cbar_E = plt.colorbar(scatter_e, pad=0.1)
cbar_E.set_label('prediction')
axes[1].legend()
axes[1].grid(True)


plt.plot();
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
