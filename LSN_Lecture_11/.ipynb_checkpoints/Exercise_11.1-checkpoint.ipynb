# %% [markdown]
# # Exercise 11.1

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %%
import numpy as np
import matplotlib.pyplot as plt

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 500)
x_valid = np.random.uniform(-1, 1, 50)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.2 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Input(shape=(1,)))
model.add(Dense(1))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
model.set_weights(initial_weights);
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=150,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid));

save_model_path=('Saved/intro_model_' + str(i) + '.keras');
model.save(filepath=save_model_path, include_optimizer=True);
# Out:
# Epoch 1/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3188 - mse: 2.3188 - val_loss: 1.8902 - val_mse: 1.8902
# Epoch 2/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6863 - mse: 1.6863 - val_loss: 1.3897 - val_mse: 1.3897
# Epoch 3/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2579 - mse: 1.2579 - val_loss: 1.0539 - val_mse: 1.0539
# Epoch 4/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9630 - mse: 0.9630 - val_loss: 0.8178 - val_mse: 0.8178
# Epoch 5/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7519 - mse: 0.7519 - val_loss: 0.6459 - val_mse: 0.6459
# Epoch 6/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5955 - mse: 0.5955 - val_loss: 0.5158 - val_mse: 0.5158
# Epoch 7/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4763 - mse: 0.4763 - val_loss: 0.4162 - val_mse: 0.4162
# Epoch 8/150
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3842 - mse: 0.3842 - val_loss: 0.3396 - val_mse: 0.3396
# Epoch 9/150
# ...

# %%
plt.figure(figsize=(8, 8))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Andamento loss")
plt.xlabel("Epoche")
plt.ylabel("Loss")
plt.legend(['Train', 'Test'], loc='best')
plt.grid(True, linestyle=':', alpha=0.7)

#plt.axis('equal') 

plt.show()

# %%
ntrain_vec = [50, 100, 500, 1000, 5000]
scores = np.zeros((len(epochs_vec), 2));

for i, ntrain in enumerate(ntrain_vec):
    x_train = np.random.uniform(-1, 1, ntrain)
    x_valid = np.random.uniform(-1, 1, ntrain./10)
    x_valid.sort()
    y_target = m * x_valid + b # ideal (target) linear function
    
    sigma = 0.2 # noise standard deviation, for the moment it is absent
    y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
    y_valid = np.random.normal(m * x_valid + b, sigma)

    initial_weights = model.get_weights();
    model.set_weights(initial_weights);
    history2 = model.fit(x=x_train, y=y_train, 
              batch_size=32, epochs=30,
              shuffle=True, # a good idea is to shuffle input before at each epoch
              validation_data=(x_valid, y_valid));
    scores[i,0] = history.history['loss'][-1];
    scores[i,1] = history.history['val_loss'][-1];
    save_model_path=('Saved/intro_model_' + str(i) + '.keras');
    model.save(filepath=save_model_path, include_optimizer=True);
# Out:
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0350 - val_mse: 0.0350
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0421 - mse: 0.0421 - val_loss: 0.0351 - val_mse: 0.0351
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0421 - mse: 0.0421 - val_loss: 0.0352 - val_mse: 0.0352
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0352 - val_mse: 0.0352
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0353 - val_mse: 0.0353
# Epoch 9/30
# ...

# %%
plt.figure(figsize=(8, 8))

plt.scatter(ntrain_vec, scores[:,0])
plt.scatter(ntrain_vec, scores[:,1])

plt.title("Andamento loss")
plt.xlabel("Numero di punti")
plt.ylabel("Loss")
plt.legend(['Train', 'Test'], loc='best')
plt.grid(True, linestyle=':', alpha=0.7)

#plt.axis('equal') 

plt.show()
